# %% [markdown]
# <a href="https://colab.research.google.com/github/mrh-rakib/AI-cybersec/blob/main/lab1_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! ls
# Out:
# sample_data

# %%
! pip install numpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# %timeit print("test")
# Out:
# Streaming output truncated to the last 5000 lines.
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# ...

# %%
# !pwd
# Out:
# /content

# %%
# %cd sample_data
# Out:
# /content/sample_data

# %%
# %pwd
# Out:
# '/content/sample_data'

# %%
# %ls
# Out:
# anscombe.json*                mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md*

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
with open('/content/gdrive/MyDrive/AICS/file.txt','r') as f:
  data=f.read()

# %%
data
# Out:
# 'Welcome to ICT607!'

# %%
! git clone https://github.com/mrh-rakib/mrh-rakib.github.ioe
# Out:
# Cloning into 'mrh-rakib.github.io'...
# remote: Enumerating objects: 1528, done.
# remote: Counting objects: 100% (447/447), done.
# remote: Compressing objects: 100% (200/200), done.
# remote: Total 1528 (delta 311), reused 371 (delta 239), pack-reused 1081
# Receiving objects: 100% (1528/1528), 70.93 MiB | 43.94 MiB/s, done.
# Resolving deltas: 100% (976/976), done.
